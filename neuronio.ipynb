# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
x = range(1,100,1)

# %%
y = []
for i in x:
    y.append(i**2)

# %%
plt.plot(x,y)
plt.title('Gráfico a ser estimado')
plt.xlabel('Tempo')
plt.ylabel('f(x)')
# Out:
# Text(0,0.5,'f(x)')

# %%
wi = [0.1]
out = [0.1]

# %%
for e in range(0,10,1):
    err = 0
    for i in x:
# Out:
#   File "<ipython-input-26-770d6b5da425>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
def dot(x,y):
    res = []
    for i in range(0, len(x)):
        res[i] = x[i] * y[i]
    return res
